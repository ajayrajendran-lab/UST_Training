# %%
import pandas as pd
ipldf=pd.read_csv(r"\Users\Administrator\Desktop\Training\IPL Matches 2008-2020.csv")
print(ipldf)
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipldf.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
ipldf.head(10)
ipldf.tail(40)
# Out:
#           id       city        date player_of_match  \
# 776  1216512  Abu Dhabi  2020-10-18     LH Ferguson
# 777  1216513      Dubai  2020-10-04       SR Watson
# 778  1216514  Abu Dhabi  2020-10-03       YS Chahal
# 779  1216515    Sharjah  2020-10-03         SS Iyer
# 780  1216516      Dubai  2020-10-02         PK Garg
# 781  1216517      Dubai  2020-10-18        KL Rahul
# 782  1216518      Dubai  2020-10-22       MK Pandey
# 783  1216519      Dubai  2020-10-05        AR Patel
# 784  1216520    Sharjah  2020-10-26        CH Gayle
# 785  1216521    Sharjah  2020-10-23        TA Boult
# 786  1216522      Dubai  2020-10-17  AB de Villiers
# 787  1216523  Abu Dhabi  2020-10-10      KD Karthik
# 788  1216524      Dubai  2020-10-27         WP Saha
# 789  1216525      Dubai  2020-10-10         V Kohli
# 790  1216526  Abu Dhabi  2020-10-16       Q de Kock
# 791  1216527    Sharjah  2020-09-27       SV Samson
# 792  1216528      Dubai  2020-10-13       RA Jadeja
# ...

# %%
ipldf['winner']
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 811    Royal Challengers Bangalore
# 812                 Mumbai Indians
# 813            Sunrisers Hyderabad
# 814                 Delhi Capitals
# 815                 Mumbai Indians
# Name: winner, Length: 816, dtype: object

# %%
ipldf['player_of_match']
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 811    AB de Villiers
# 812         JJ Bumrah
# 813     KS Williamson
# 814        MP Stoinis
# 815          TA Boult
# Name: player_of_match, Length: 816, dtype: object

# %%
champions = ipldf['winner'].value_counts().idxmax() #teams which became most number of champions

# %%
print(champions)
# Out:
# Mumbai Indians

# %%
no_champions = ipldf['winner'].value_counts().count()
print(no_champions) #no of times mumbai indians become the champions
# Out:
# 15

# %%
teams_and_winnings=ipldf['winner'].value_counts()
print(teams_and_winnings)
# Out:
# winner
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
dup_ipl_df=ipldf
dup_ipl_df=dup_ipl_df['id'].astype('float')
# print(dup_ipl_df)
print(dup_ipl_df.dtypes)
# Out:
# float64

# %%
winners=ipldf.winner.describe()
winners=pd.DataFrame(winners)
print(winners)
print(type(winners))
# Out:
#                 winner
# count              812
# unique              15
# top     Mumbai Indians
# freq               120
# <class 'pandas.core.frame.DataFrame'>

# %%
result_iloc=winners.loc[[3, 1]]
print(result_iloc)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 result_iloc=winners.loc[[3, 1]]
#       2 print(result_iloc)
#
# File C:\Program Files\Python311\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\Program Files\Python311\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# ...

# %%
ipldf2=ipldf['method'].fillna('Dubai')
print(ipldf2)
# Out:
# 0      Dubai
# 1      Dubai
# 2      Dubai
# 3      Dubai
# 4      Dubai
#        ...
# 811    Dubai
# 812    Dubai
# 813    Dubai
# 814    Dubai
# 815    Dubai
# Name: method, Length: 816, dtype: object

# %%
counts=ipldf.count()
print(counts)
# Out:
# id                 816
# city               803
# date               816
# player_of_match    812
# venue              816
# neutral_venue      816
# team1              816
# team2              816
# toss_winner        816
# toss_decision      816
# winner             812
# result             812
# result_margin      799
# eliminator         812
# method              19
# umpire1            816
# umpire2            816
# dtype: int64

# %%
ds['winner'][ds['player_of_match']=="Rain"]

# %%
pom=ipldf.player_of_match.describe()
print(pom)
# Out:
# count                812
# unique               233
# top       AB de Villiers
# freq                  23
# Name: player_of_match, dtype: object

# %%
ipldf['date'][ipldf['city']=='Bangalore' ipldf['winner']=='Mumbai']
# print(bangalore_matches)
# Out:
# 0      2008-04-18
# 10     2008-04-26
# 14     2008-04-28
# 24     2008-05-05
# 30     2008-05-28
#           ...
# 606    2017-04-27
# 618    2017-05-05
# 621    2017-05-07
# 633    2017-05-17
# 634    2017-05-19
# Name: date, Length: 65, dtype: object
